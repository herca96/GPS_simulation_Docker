# %%
import time
import mysql.connector
import requests
import urllib.request

import json
import configparser as cfg
import numpy as np

import telegram.ext
from telegram import ReplyKeyboardMarkup

from datetime import datetime
import random

#import pandas as pd
#import os
#from bokeh.io import output_notebook
#import telegram
#import urllib.request#, json



class databasechatbot(object):
    def __init__(self):

        self.offset = 1
        self.urlold = "start"
        self.i = 0
        self.update_id = 1
        self.urlupdategrenze = 50
        
        #database
        self.databaseuser='server_bergnungpython'
        self.databasepwd='RHlSEVvFAr6kVcFr'
        self.databasehost='162.55.0.136'
        self.database='server_Beregnung'
        
        #telegram
        self.tokens = "6216581879:AAGZAKidYqS_OhtxYMlg61D2RgB6daXjq4c"
        self.base = "https://api.telegram.org/bot{}/".format(self.tokens)
        
        #self.cnx = mysql.connector.connect(user='server_bergnungpython', password='RHlSEVvFAr6kVcFr',host='server.bplaced.net',database='server_Beregnung')
        print("init")
        
    def databaseconnectio(self):
        self.cnx = mysql.connector.connect(user=self.databaseuser, password=self.databasepwd,host=self.databasehost,database=self.database)
        #print("init")
        
        runcon = False
        
        while runcon == False:
    

            try:

                self.cnx = mysql.connector.connect(user=self.databaseuser, password=self.databasepwd,host=self.databasehost,database=self.database)
                if (self.cnx.is_connected()):
                    print("Connected")
                    runcon = True
        
                self.mycursor = self.cnx.cursor()

            except Exception as e:

                dt = datetime.datetime.now(timezone.utc)
                utc_time = dt.replace(tzinfo=timezone.utc)
                utc_timestamp_now = utc_time.timestamp()

                dt_string = str(utc_timestamp_now)
                dt_string = str(utc_time.strftime("%d/%m/%Y %H:%M:%S"))
                with open("log.txt","a") as error:
                    error.write(""+dt_string+" dyn"+str(e)+"\n")
        
                print("connect failed")
                print(e)
                runcon = False

        return self.mycursor

    def get_updates(self):
        
        '''
        try:

            url = self.base + "getUpdates?timeout=1"
            url = url + "&offset={}".format(self.update_id + self.offset)
            r = requests.get(url)
            #print(url)
            
        except:
            print("no update")
        #print(self.urlold)
        #idnow=url.lstrip("https://api.telegram.org/bot1061616188:AAFJIaCjjQ3N-iGegrrexclCNtg4BJblhwA/getUpdates?timeout=2&offset")
        #idnow =int(idnow)
        #print()
        #if url==self.urlold:
        #    self.i+=1
        #    print(self.i)
        #    self.offset = 1
            
        #if self.i==self.urlupdategrenze:
         #   self.offset = 2
         #   self.i=0
            
        self.urlold = url  

        '''
        runcon = False
        
        while runcon == False:

            print("second")

            try:

                print("third")
                url = self.base + "getUpdates?timeout=1"
                print(5)
                url = url + "&offset={}".format(self.update_id + self.offset)
                print(6)
                #time.sleep(3)
                r = requests.get(url,timeout=4)
                print(r)
                print(7)
                print("Connected_telegram")
                runcon = True

            except Exception as e:
        
                print("connect failed")
                print(e)
                runcon = False                 

        return json.loads(r.content)
    
    def send_keyboard(self):
        self.mycursor = self.databaseconnectio()
        chat_ids=[]
        #mycursor = self.cnx.cursor()
        self.mycursor.execute("SELECT telgrammchatid_1,telgrammchatid_2,telgrammchatid_3 FROM benutzerdaten_demo")  
        mods = self.mycursor.fetchall()

        for x in mods:

            chat_ids.append(x[0])
            chat_ids.append(x[1])
            chat_ids.append(x[2])
        chat_ids = list(dict.fromkeys(chat_ids))
        chat_ids.remove('')
        #print(chat_ids)
        
        for chat_id in chat_ids:
            menu_keyboard = [['/aktueller_Standort']] #angepasst
            menu_markup = ReplyKeyboardMarkup(menu_keyboard, one_time_keyboard=False, resize_keyboard=True, remove_keyboard=True)
            self.bot.send_message(chat_id=chat_id,text="restart bot", reply_markup=menu_markup)
        self.mycursor.close()

    def send_message(self, msg, chat_id, moduls, betriebsnummerarray):
        
        #moduls, betriebsnummerarray = objName.module(str(chat_id))#+++++++
        
        if msg == "/aktueller_Standort" or msg == "/start": #angepasst
            
            menu_keyboard = np.array(moduls).reshape(-1, 1)
            menu_markup = ReplyKeyboardMarkup(menu_keyboard, one_time_keyboard=False, resize_keyboard=True, remove_keyboard=False)
            #print(chat_id)
            self.bot.send_message(chat_id=chat_id,text="wähle eine Beregnung aus", reply_markup=menu_markup)
        
        if msg in moduls:

            latarray=[]
            lngarray=[]
            statusarray=[]
            
            msg= msg.replace("/", "") #angepasst
            #mycursor = self.cnx.cursor()
            print("betriebsnumarray")
            print(betriebsnummerarray[0])
            self.mycursor = self.databaseconnectio()
            self.mycursor.execute("SELECT * FROM all_in_one_demo WHERE Modulname = '"+msg+"'AND Betriebsnummer = '"+betriebsnummerarray[0]+"' AND Lat != 'X' ORDER BY Zeit DESC LIMIT 1")
            status = self.mycursor.fetchall()
            self.mycursor.close()
            for z in status:

                latarray.append(z[7])
                lngarray.append(z[8])
                statusarray.append(z[11])
            
            #print(chat_id,latarray[0], lngarray[0])
            #latn = round(float(latarray[0]),1)
            #lngn = round(float(lngarray[0]),1)
             
            
            #print(latn, lngn)
            
            
            if statusarray[0]=="0":
                msg = msg+' ❌'
                #print("hdf")
            if statusarray[0]=="1":
                msg = msg+' ✅'
                
            menu_keyboard = [['/aktueller_Standort']] #angepasst
            menu_markup = ReplyKeyboardMarkup(menu_keyboard, one_time_keyboard=False, resize_keyboard=True, remove_keyboard=False)
            print(latarray[0])
            print(lngarray[0])
            self.bot.send_location(chat_id,latarray[0], lngarray[0])
            self.bot.send_message(chat_id=chat_id,text=msg, reply_markup=menu_markup) 
            
    #def send_button(self, msg, chat_id):
       # url = self.base + "reply_markup?chat_id={}&text={}".format(chat_id, msg)
       # print("hi")
       # if msg is not None:
           # requests.get(url)
            
    def module(self,chat_id):
        
        self.mycursor = self.databaseconnectio()
        betriebsnumarray=[]
        moarray=[]
        #print("cnx:")
        #print(self.cnx)
        
        #t= self.cnx
        #mycursor = t.cursor()
        
        self.mycursor.execute("SELECT * FROM benutzerdaten_demo WHERE telgrammchatid_1 = '"+chat_id+"' OR telgrammchatid_2 = '"+chat_id+"' OR telgrammchatid_3 = '"+chat_id+"'")  
        mods = self.mycursor.fetchall()

        self.mycursor.close()

        for x in mods:

            betriebsnumarray.append(x[9])

        betriebsnumarray = list(dict.fromkeys(betriebsnumarray))
        
        self.mycursor = self.databaseconnectio()
        self.mycursor.execute("SELECT * FROM all_in_one_demo WHERE Betriebsnummer = '"+betriebsnumarray[0]+"'")  
        mo = self.mycursor.fetchall()
        self.mycursor.close()
        
        for y in mo:

            moarray.append("/"+y[3])
            #print(y[3])
        moarray = list(dict.fromkeys(moarray))
        #print(moarray)

        return moarray, betriebsnumarray
                        
    def main(self):
    
    
        try:
            #self.internet_on()
            self.bot = telegram.Bot(token=self.tokens)
            #self.mycursor = self.databaseconnectio()
            self.send_keyboard()
            
        except:
            print("wrong start")
            
        while True:
            
            try:
                self.bot = telegram.Bot(token=self.tokens)
                #self.bot.close()
                updates=[]
                item=[]
                moduls=[]
                betriebsnummerarray=[]
                message = None

                print("random")
                print(random.randint(0,9))
                print("first")
                updates = self.get_updates()
                print(updates)
                updates = updates["result"]


                if updates:
                    for item in updates:

                        self.update_id = item["update_id"]
                        message = str(item["message"]["text"])
                        from_ = item["message"]["chat"]["id"]
                        
                        sec_post = item["message"]["date"]
                        sec_now = int(round(time.time()))
                        
                        time_dif = sec_now-int(sec_post)
                        #print("-----")
                        #print(time_dif)
                        #print("-----")
                        
                        if time_dif<100:
                            
                            #self.mycursor = self.databaseconnectio()
                            moduls, betriebsnummerarray = self.module(str(from_))
                            #print(moduls)
                            #print("---------")
                            self.send_message(message, from_, moduls, betriebsnummerarray)
                            #self.mycursor.close()
                        
            except:
                print("retry")
            
            #except Exception as e:
            
            #    now = datetime.now()
 
            #    print("now =", now)
            #    dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
            #    with open("log.txt","a") as error:
            #        error.write(""+dt_string+" dyn"+str(e)+"\n")
                    
            #    print(e)
            #    print("retry")        
            

if __name__ == '__main__':
    objName = databasechatbot()
    objName.main()
# Out:
# init
# Connected
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936522, 'message': {'message_id': 1680, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408277, 'reply_to_message': {'message_id': 1678, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1677181411, 'text': 'Philipp ❌'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}, {'update_id': 68936523, 'message': {'message_id': 1686, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408378, 'reply_to_message': {'message_id': 1678, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1677181411, 'text': 'Philipp ❌'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936524, 'message': {'message_id': 1690, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408669, 'reply_to_message': {'message_id': 1689, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408656, 'text': 'restart bot'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936525, 'message': {'message_id': 1692, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408671, 'reply_to_message': {'message_id': 1691, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408670, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.382485
# 10.328196
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936526, 'message': {'message_id': 1697, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408688, 'reply_to_message': {'message_id': 1694, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408674, 'text': 'DeierlingX ❌'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936527, 'message': {'message_id': 1699, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408690, 'reply_to_message': {'message_id': 1698, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408689, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.38279
# 10.330706
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936528, 'message': {'message_id': 1702, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408694, 'reply_to_message': {'message_id': 1701, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408692, 'text': 'DeierlingX ✅'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936529, 'message': {'message_id': 1704, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408696, 'reply_to_message': {'message_id': 1703, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408695, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.382745
# 10.330296
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936530, 'message': {'message_id': 1707, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408700, 'reply_to_message': {'message_id': 1706, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408698, 'text': 'DeierlingX ✅'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936531, 'message': {'message_id': 1709, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408702, 'reply_to_message': {'message_id': 1708, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408701, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.382603
# 10.3297
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936532, 'message': {'message_id': 1712, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408705, 'reply_to_message': {'message_id': 1711, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408703, 'text': 'DeierlingX ✅'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936533, 'message': {'message_id': 1714, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408707, 'reply_to_message': {'message_id': 1713, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408706, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.382603
# 10.3297
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936534, 'message': {'message_id': 1717, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408710, 'reply_to_message': {'message_id': 1716, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408709, 'text': 'DeierlingX ✅'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936535, 'message': {'message_id': 1719, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408712, 'reply_to_message': {'message_id': 1718, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408711, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.382553
# 10.329196
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936536, 'message': {'message_id': 1722, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408716, 'reply_to_message': {'message_id': 1721, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408714, 'text': 'DeierlingX ✅'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936537, 'message': {'message_id': 1724, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408718, 'reply_to_message': {'message_id': 1723, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408717, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.382553
# 10.329196
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936538, 'message': {'message_id': 1727, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408721, 'reply_to_message': {'message_id': 1726, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408720, 'text': 'DeierlingX ✅'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936539, 'message': {'message_id': 1729, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408723, 'reply_to_message': {'message_id': 1728, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Test46', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408722, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.382526
# 10.328746
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936540, 'message': {'message_id': 1732, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Demo Hof', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408777, 'new_chat_title': 'Demo Hof'}}]}
# retry
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936541, 'message': {'message_id': 1735, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Demo Hof', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408805, 'reply_to_message': {'message_id': 1731, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Demo Hof', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408725, 'text': 'DeierlingX ✅'}, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936542, 'message': {'message_id': 1737, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Demo Hof', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408807, 'reply_to_message': {'message_id': 1736, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Demo Hof', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1686408806, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.382485
# 10.328196
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936543, 'message': {'message_id': 1744, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Demo Hof', 'type': 'group', 'all_members_are_administrators': False}, 'date': 1686409133, 'text': '/aktueller_Standort', 'entities': [{'offset': 0, 'length': 19, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': [{'update_id': 68936544, 'message': {'message_id': 1746, 'from': {'id': 850790486, 'is_bot': False, 'first_name': 'C', 'last_name': 'H', 'username': 'herca96', 'language_code': 'de'}, 'chat': {'id': -814099206, 'title': 'Demo Hof', 'type': 'group', 'all_members_are_administrators': False}, 'date': 1686409139, 'reply_to_message': {'message_id': 1745, 'from': {'id': 6216581879, 'is_bot': True, 'first_name': 'Beregnung_test_bot', 'username': 'Beregnung_test_bot'}, 'chat': {'id': -814099206, 'title': 'Demo Hof', 'type': 'group', 'all_members_are_administrators': False}, 'date': 1686409134, 'text': 'wähle eine Beregnung aus'}, 'text': '/DeierlingX', 'entities': [{'offset': 0, 'length': 11, 'type': 'bot_command'}]}}]}
# Connected
# Connected
# betriebsnumarray
# 46
# Connected
# 52.382485
# 10.328196
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 4
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 9
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 5
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 6
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 7
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 0
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 2
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 8
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 3
# first
# second
# third
# 5
# 6
# <Response [200]>
# 7
# Connected_telegram
# {'ok': True, 'result': []}
# random
# 1
# first
# second
# third
# 5
# 6
